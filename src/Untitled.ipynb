# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import cv2 as cv
import os
# Out:
# C:\Users\Atharva Darke\AppData\Local\Temp\ipykernel_2212\3747827840.py:6: DeprecationWarning: 'imghdr' is deprecated and slated for removal in Python 3.13
#   import imghdr

# %%
pip install imgdhr
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement imgdhr (from versions: none)
# ERROR: No matching distribution found for imgdhr

# %%
img = cv.imread(r"C:\Users\Atharva Darke\Desktop\data_markly\Atharva_8.jpg",1)
img_rgb = img[:,:,::-1]
img_gray = cv.cvtColor(img,cv.COLOR_RGB2GRAY)
retval,img_mask = cv.threshold(img_gray,70,255,cv.THRESH_BINARY)

# %%
plt.figure(figsize=(10,5))
plt.subplot(141);plt.imshow(img);plt.title("BGR image")
plt.subplot(142);plt.imshow(img_rgb);plt.title("RGB_image")
plt.subplot(143);plt.imshow(img_gray);plt.title("Grayscale image")
plt.subplot(144);plt.imshow(img_mask);plt.title("Binary image")
# Out:
# Text(0.5, 1.0, 'Binary image')

# %%
# data = tf.constant(r"C:\Users\Atharva Darke\Desktop\My_Project\git_repos\Markly\data\Atharva")

# %%
data = r"C:\Users\Atharva Darke\Desktop\My_Project\git_repos\Markly\data"
data_extensions = ['jpg','jpeg','png']
# data = os.listdir(os.path.join(data,'Atharva'))

# %%
for image_class in (os.listdir(data)):
    for items in (os.listdir(os.path.join(data,'Atharva'))):
        img_path = os.path.join(data,image_class,items)
        
        print(cv.imread(img_path))
# Out:
# [[[ 70 145  67]
#   [ 74 149  71]
#   [ 82 157  79]
#   ...
#   [159 180 172]
#   [161 182 174]
#   [164 181 177]]
#
#  [[ 64 139  61]
#   [ 70 145  67]
#   [ 78 153  75]
#   ...
#   [160 181 173]
#   [161 182 174]
#   [165 182 178]]
#
#  [[ 62 138  60]
#   [ 67 143  65]
#   [ 73 150  69]
#   ...
#   [161 182 174]
#   [162 183 175]
#   [166 183 179]]
#
#  ...
#
#  [[  5   2 232]
#   [  4   1 230]
#   [  4   0 226]
#   ...
#   [  0   1 186]
#   [  0   1 186]
#   [  0   1 186]]
#
#  [[  5   2 232]
#   [  4   1 230]
#   [  4   0 226]
#   ...
#   [  1   0 186]
#   [  1   0 186]
#   [  1   0 186]]
#
#  [[  4   1 231]
#   [  3   0 229]
#   [  3   0 225]
#   ...
#   [  1   0 186]
#   [  1   0 186]
#   [  1   0 186]]]
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
# ...

# %%
tf.keras.utils.image_dataset_from_directory??
# Out:
# Signature:
# tf.keras.utils.image_dataset_from_directory(
#     directory,
#     labels='inferred',
#     label_mode='int',
#     class_names=None,
#     color_mode='rgb',
#     batch_size=32,
#     image_size=(256, 256),
#     shuffle=True,
#     seed=None,
#     validation_split=None,
#     subset=None,
#     interpolation='bilinear',
#     follow_links=False,
#     crop_to_aspect_ratio=False,
#     pad_to_aspect_ratio=False,
#     data_format=None,
#     verbose=True,
# )
# Source:
# @keras_export(
#     [
#         "keras.utils.image_dataset_from_directory",
#         "keras.preprocessing.image_dataset_from_directory",
#     ]
# )
# def image_dataset_from_directory(
#     directory,
#     labels="inferred",
#     label_mode="int",
#     class_names=None,
#     color_mode="rgb",
#     batch_size=32,
#     image_size=(256, 256),
#     shuffle=True,
#     seed=None,
#     validation_split=None,
#     subset=None,
#     interpolation="bilinear",
#     follow_links=False,
# ...

# %%
dataset = tf.keras.utils.image_dataset_from_directory(
    data,
    labels='inferred',
    label_mode = 'categorical',
    image_size = ()
)
# Out:
# Found 10 files belonging to 1 classes.
